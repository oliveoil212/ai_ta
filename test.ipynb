# %%
from openai import OpenAI
from My_API import GPT
import os
from dotenv import load_dotenv
import time
import logging
# from Record import record_audio
# from dotenv import find_dotenv, load_dotenv
import torch
from TTS.api import TTS
from pydub import AudioSegment
from pydub.playback import play
import IPython.display as ipd
load_dotenv()

client = OpenAI(
  api_key=os.environ.get("OPENAI_API_KEY"),
)

# %%
assistant_id = 'asst_HoQdrYDlaBKNOgKqVUf0oldZ'
assistant = client.beta.assistants.retrieve(assistant_id)

# %%
TA = GPT(client,assistant)

# Get device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
import tqdm as notebook_tqdm

# %%
# List available 🐸TTS models
print(TTS().list_models())

# Init TTS
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)
# Out:
# ...
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts

# %%
TA.new_thread()
user_input = ''
while user_input != '!q':   # 當 user 輸入 q 時跳出去!
    user_input = input('enter cmd: ')
    if user_input=='clear':  # 當 user 輸入 clear 時
        clear_output(wait=False) # 立即清空目前 cell 的內容
    else:
        print(f"user: {user_input}") 
        TA.prompt_and_run(user_input)
        response = TA.get_last_response()
        print(f'TA: {response}')

        tts.tts_to_file(text=response, speaker_wav="./CSC_4min.wav", language="en", file_path="output.wav")

        # ipd.Audio('output.wav') 
        # # for playing wav file
        # speech = AudioSegment.from_wav("output.wav")
        # print('playing sound using  pydub')
        # play(speech)
# Out:
# user:
# TA: How can I assist you today?
#  > Text splitted to sentences.
# ['How can I assist you today?']
#  > Processing time: 1.76291823387146
#  > Real-time factor: 0.8527629663229574
# user: what is tcp ip
# TA: TCP/IP stands for Transmission Control Protocol/Internet Protocol, which is a suite of communication protocols used to interconnect network devices on the internet. TCP/IP specifies how data is exchanged over the internet by providing end-to-end communications that identify how it should be broken into packets, addressed, transmitted, routed, and received at the destination.
#
# TCP/IP has two layers of protocols:
#
# 1. **The Transmission Control Protocol (TCP)** - This layer is responsible for breaking down messages into packets, transferring them from source to destination, and then reassembling them into the original message. TCP also ensures that packets are delivered error-free, in sequence, and without losses or duplications.
#
# ...

# %%
# from ipywebrtc import AudioRecorder, CameraStream
# import torchaudio
# from IPython.display import Audio
# recorder = AudioRecorder(stream=camera)
# recorder

# %%
speech = AudioSegment.from_wav("output.wav")
print('playing sound using  pydub')
play(speech)
# Out:
# playing sound using  pydub
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5180:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5180:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5180:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5703:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM sysdefault
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5180:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ...

# %%
# Get device
device = "cuda" if torch.cuda.is_available() else "cpu"

# List available 🐸TTS models
print(TTS().list_models())

# Init TTS
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)

# Run TTS
# ❗ Since this model is multi-lingual voice cloning model, we must set the target speaker_wav and language
# Text to speech list of amplitude values as output
# wav = tts.tts(text="Hello world!", speaker_wav="./CSC_4min.wav", language="en")
# Text to speech to a file
tts.tts_to_file(text="Hello world!", speaker_wav="./CSC_4min.wav", language="en", file_path="output.wav")
# Out:
# ...
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       5 print(TTS().list_models())
#       7 # Init TTS
# ----> 8 tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)
#      10 # Run TTS
#      11 # ❗ Since this model is multi-lingual voice cloning model, we must set the target speaker_wav and language
#      12 # Text to speech list of amplitude values as output
#      13 # wav = tts.tts(text="Hello world!", speaker_wav="./CSC_4min.wav", language="en")
#      14 # Text to speech to a file
#      15 tts.tts_to_file(text="Hello world!", speaker_wav="./CSC_4min.wav", language="en", file_path="output.wav")
#
# ...

# %%
import IPython.display as ipd
ipd.Audio('output.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from pydub import AudioSegment
from pydub.playback import play
 
# for playing wav file
song = AudioSegment.from_wav("output.wav")
print('playing sound using  pydub')
play(song)
# Out:
# playing sound using  pydub
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5180:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5180:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5180:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5703:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM sysdefault
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5180:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ...
